# %%
import requests
import time
import pandas as pd

# %%
sample_data = {
    "features": [
         0.0,
  -1.3598071336738,
  -0.0727811733098497,
  2.53634673796914,
  1.37815522427443,
  -0.338320769942518,
  0.462387777762292,
  0.239598554061257,
  0.0986979012610507,
  0.363786969611213,
  0.0907941719789316,
  -0.551599533260813,
  -0.617800855762348,
  -0.991389847235408,
  -0.311169353699879,
  1.46817697209427,
  -0.470400525259478,
  0.207971241929242,
  0.0257905801985591,
  0.403992960255733,
  0.251412098239705,
  -0.018306777944153,
  0.277837575558899,
  -0.110473910188767,
  0.0669280749146731,
  0.128539358273528,
  -0.189114843888824,
  0.133558376740387,
  -0.0210530534538215,
  149.62,
    ]
}

# %%
latencies = []

url = "http://127.0.0.1:5000/predict"

for i in range(100):

    start = time.perf_counter()

    response = requests.post(
        url,
        json=sample_data
    )

    end = time.perf_counter()

    latency_ms = (end - start) * 1000

    latencies.append(latency_ms)

print("Completed")
# Out:
# Completed

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))

plt.hist(latencies, bins=15)

plt.title("API Latency Distribution")
plt.xlabel("Latency (ms)")
plt.ylabel("Frequency")

plt.show()

# %%
results = pd.DataFrame({
    "Latency(ms)": latencies
})

print("Average Latency:", results["Latency(ms)"].mean())
print("Minimum Latency:", results["Latency(ms)"].min())
print("Maximum Latency:", results["Latency(ms)"].max())
# Out:
# Average Latency: 54.9060809990624
# Minimum Latency: 44.69379998045042
# Maximum Latency: 245.21890003234148
